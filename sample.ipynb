# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click !here goes the icon of the corresponding button in the gutter! button.
# To debug a cell, press Alt+Shift+Enter, or click !here goes the icon of the corresponding button in the gutter! button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/jupyter-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
# !nvidia-smi

# %%
# !pip install -Uqqq pip --progress-bar off
# !pip install -qqq torch==2.3.1 --progress-bar off
# !pip install -qqq datasets==2.20.0 --progress-bar off
# !pip install -qqq accelerate==0.31.0 --progress-bar off
# !pip install -qqq bitsandbytes==0.43.1 --progress-bar off
# !pip install -qqq peft==0.11.1 --progress-bar off
# !pip install -qqq trl==0.9.4 --progress-bar off
# !pip install -qqq colored==2.2.4 --progress-bar off
# Out:
# ERROR: To modify pip, please run the following command:
# C:\Users\cem\.conda\envs\LlamaFineTune\python.exe -m pip install -Uqqq pip --progress-bar off
# ERROR: Ignored the following yanked versions: 4.14.0, 4.25.0
# ERROR: Could not find a version that satisfies the requirement transformers==4.41.3 (from versions: 0.1, 2.0.0, 2.1.0, 2.1.1, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.8.0, 2.9.0, 2.9.1, 2.10.0, 2.11.0, 3.0.0, 3.0.1, 3.0.2, 3.1.0, 3.2.0, 3.3.0, 3.3.1, 3.4.0, 3.5.0, 3.5.1, 4.0.0rc1, 4.0.0, 4.0.1, 4.1.0, 4.1.1, 4.2.0, 4.2.1, 4.2.2, 4.3.0rc1, 4.3.0, 4.3.1, 4.3.2, 4.3.3, 4.4.0, 4.4.1, 4.4.2, 4.5.0, 4.5.1, 4.6.0, 4.6.1, 4.7.0, 4.8.0, 4.8.1, 4.8.2, 4.9.0, 4.9.1, 4.9.2, 4.10.0, 4.10.1, 4.10.2, 4.10.3, 4.11.0, 4.11.1, 4.11.2, 4.11.3, 4.12.0, 4.12.1, 4.12.2, 4.12.3, 4.12.4, 4.12.5, 4.13.0, 4.14.1, 4.15.0, 4.16.0, 4.16.1, 4.16.2, 4.17.0, 4.18.0, 4.19.0, 4.19.1, 4.19.2, 4.19.3, 4.19.4, 4.20.0, 4.20.1, 4.21.0, 4.21.1, 4.21.2, 4.21.3, 4.22.0, 4.22.1, 4.22.2, 4.23.0, 4.23.1, 4.24.0, 4.25.1, 4.26.0, 4.26.1, 4.27.0, 4.27.1, 4.27.2, 4.27.3, 4.27.4, 4.28.0, 4.28.1, 4.29.0, 4.29.1, 4.29.2, 4.30.0, 4.30.1, 4.30.2, 4.31.0, 4.32.0, 4.32.1, 4.33.0, 4.33.1, 4.33.2, 4.33.3, 4.34.0, 4.34.1, 4.35.0, 4.35.1, 4.35.2, 4.36.0, 4.36.1, 4.36.2, 4.37.0, 4.37.1, 4.37.2, 4.38.0, 4.38.1, 4.38.2, 4.39.0, 4.39.1, 4.39.2, 4.39.3, 4.40.0, 4.40.1, 4.40.2, 4.41.0, 4.41.1, 4.41.2, 4.42.0, 4.42.1, 4.42.2, 4.42.3, 4.42.4)
# ERROR: No matching distribution found for transformers==4.41.3

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (4.42.4)
# Requirement already satisfied: filelock in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy<2.0,>=1.17 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from transformers) (2.32.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Requirement already satisfied: colorama in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from requests->transformers) (2024.7.4)

# %%
# !pip install matplotlib
# !pip install numpy
# !pip install pandas
# !pip install colored
# !pip install seaborn
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.1-cp311-cp311-win_amd64.whl.metadata (165 kB)
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ------- ------------------------------- 30.7/165.9 kB 1.3 MB/s eta 0:00:01
#      --------------- --------------------- 71.7/165.9 kB 975.2 kB/s eta 0:00:01
#      -------------------------------------- 165.9/165.9 kB 1.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.4.0-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.1-cp311-cp311-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#     --------------------------------------- 0.1/8.0 MB 6.8 MB/s eta 0:00:02
#    - -------------------------------------- 0.2/8.0 MB 3.8 MB/s eta 0:00:03
#    - -------------------------------------- 0.2/8.0 MB 3.8 MB/s eta 0:00:03
#    - -------------------------------------- 0.2/8.0 MB 3.8 MB/s eta 0:00:03
#    - -------------------------------------- 0.3/8.0 MB 1.4 MB/s eta 0:00:06
#    -- ------------------------------------- 0.5/8.0 MB 2.0 MB/s eta 0:00:04
#    --- ------------------------------------ 0.6/8.0 MB 2.2 MB/s eta 0:00:04
#    --- ------------------------------------ 0.6/8.0 MB 2.2 MB/s eta 0:00:04
#    --- ------------------------------------ 0.6/8.0 MB 2.2 MB/s eta 0:00:04
#    --- ------------------------------------ 0.7/8.0 MB 1.5 MB/s eta 0:00:05
#    --- ------------------------------------ 0.7/8.0 MB 1.6 MB/s eta 0:00:05
#    ---- ----------------------------------- 0.9/8.0 MB 1.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.9/8.0 MB 1.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/8.0 MB 1.6 MB/s eta 0:00:05
#    ------ --------------------------------- 1.2/8.0 MB 1.8 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/8.0 MB 1.9 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/8.0 MB 1.9 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/8.0 MB 1.6 MB/s eta 0:00:05
#    ------- -------------------------------- 1.4/8.0 MB 1.7 MB/s eta 0:00:04
#    -------- ------------------------------- 1.7/8.0 MB 1.9 MB/s eta 0:00:04
#    -------- ------------------------------- 1.7/8.0 MB 1.9 MB/s eta 0:00:04
#    -------- ------------------------------- 1.7/8.0 MB 1.9 MB/s eta 0:00:04
#    -------- ------------------------------- 1.8/8.0 MB 1.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.0 MB 1.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.0 MB 1.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.0 MB 1.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.2/8.0 MB 1.7 MB/s eta 0:00:04
#    ------------ --------------------------- 2.4/8.0 MB 1.9 MB/s eta 0:00:03
#    ------------ --------------------------- 2.5/8.0 MB 1.9 MB/s eta 0:00:03
#    ------------ --------------------------- 2.5/8.0 MB 1.9 MB/s eta 0:00:03
#    ------------ --------------------------- 2.5/8.0 MB 1.9 MB/s eta 0:00:03
#    ------------- -------------------------- 2.7/8.0 MB 1.8 MB/s eta 0:00:03
#    -------------- ------------------------- 3.0/8.0 MB 1.9 MB/s eta 0:00:03
#    -------------- ------------------------- 3.0/8.0 MB 1.9 MB/s eta 0:00:03
#    -------------- ------------------------- 3.0/8.0 MB 1.9 MB/s eta 0:00:03
#    --------------- ------------------------ 3.0/8.0 MB 1.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 3.4/8.0 MB 2.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 3.5/8.0 MB 2.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 3.5/8.0 MB 2.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 3.5/8.0 MB 1.9 MB/s eta 0:00:03
#    ------------------- -------------------- 3.8/8.0 MB 2.0 MB/s eta 0:00:03
#    -------------------- ------------------- 4.0/8.0 MB 2.1 MB/s eta 0:00:02
#    -------------------- ------------------- 4.0/8.0 MB 2.1 MB/s eta 0:00:02
#    -------------------- ------------------- 4.0/8.0 MB 2.1 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.0 MB 2.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.5/8.0 MB 2.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.6/8.0 MB 2.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.6/8.0 MB 2.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.6/8.0 MB 2.1 MB/s eta 0:00:02
#    ------------------------ --------------- 4.9/8.0 MB 2.1 MB/s eta 0:00:02
#    ------------------------- -------------- 5.1/8.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.0 MB 2.2 MB/s eta 0:00:02
#    --------------------------- ------------ 5.4/8.0 MB 2.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.6/8.0 MB 2.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.6/8.0 MB 2.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.6/8.0 MB 2.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.6/8.0 MB 2.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.9/8.0 MB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 6.2/8.0 MB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 6.2/8.0 MB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 6.2/8.0 MB 2.2 MB/s eta 0:00:01
#    -------------------------------- ------- 6.4/8.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/8.0 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/8.0 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/8.0 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.9/8.0 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.0 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.4/8.0 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.4/8.0 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.4/8.0 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.4/8.0 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.4/8.0 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 7.4/8.0 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 7.4/8.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 2.3 MB/s eta 0:00:00
# Downloading contourpy-1.2.1-cp311-cp311-win_amd64.whl (188 kB)
#    ---------------------------------------- 0.0/188.2 kB ? eta -:--:--
#    -------- ------------------------------- 41.0/188.2 kB ? eta -:--:--
#    -------- ------------------------------- 41.0/188.2 kB ? eta -:--:--
#    ------------ -------------------------- 61.4/188.2 kB 409.6 kB/s eta 0:00:01
#    ---------------------------------------- 188.2/188.2 kB 1.3 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.1-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/2.2 MB 3.6 MB/s eta 0:00:01
#    -- ------------------------------------- 0.2/2.2 MB 3.1 MB/s eta 0:00:01
#    -- ------------------------------------- 0.2/2.2 MB 3.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.3/2.2 MB 1.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.6/2.2 MB 2.6 MB/s eta 0:00:01
#    ------------ --------------------------- 0.7/2.2 MB 2.7 MB/s eta 0:00:01
#    ------------ --------------------------- 0.7/2.2 MB 2.7 MB/s eta 0:00:01
#    ------------ --------------------------- 0.7/2.2 MB 1.9 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.2 MB 2.1 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.2 MB 2.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 2.5 MB/s eta 0:00:01
#    -------------------------- ------------- 1.5/2.2 MB 2.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.2 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.9/2.2 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 3.1 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB ? eta 0:00:00
# Downloading pillow-10.4.0-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.6 MB 7.6 MB/s eta 0:00:01
#    -------- ------------------------------- 0.5/2.6 MB 6.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.7/2.6 MB 5.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.1/2.6 MB 6.1 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.6 MB 6.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.5/2.6 MB 5.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.8/2.6 MB 5.8 MB/s eta 0:00:01
#    ------------------------------- -------- 2.0/2.6 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------ --- 2.3/2.6 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 5.6 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.1 pillow-10.4.0 pyparsing-3.1.2
# Requirement already satisfied: numpy in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: colored in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (2.2.4)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from seaborn) (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\cem\.conda\envs\llamafinetune\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/294.9 kB 487.6 kB/s eta 0:00:01
#    -------------------- ------------------- 153.6/294.9 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 256.0/294.9 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
# !pip install scikit-learn
# !pip install

# %%
import random
from textwrap import dedent
from typing import Dict, List
import matplotlib as mpl
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import torch
from colored import Back, Fore, Style
from datasets import Dataset, load_dataset
from matplotlib.ticker import PerfectFormatter

# %%
from peft import (
    LoraConfig,
    PeftModel,
    TaskType,
    get_peft_model,
    prepare_model_for_kbit_training,
)

# %%
from sklearn.model_selection import train_test_split
